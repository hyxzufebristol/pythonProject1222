# %%
import pandas as pd
df_concat=pd.read_csv('df_concat.csv')

# %%
df_concat.shape
# Out:
# (249632, 66)

# %%
# 新增六个项目内容
# 合并完成内容在concat数据集当中
import pandas as pd
from matplotlib import pyplot as plt
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud

from config import *

# 2. the most top 30 words in newreview data
# the reviews are mainly from the 'comment' column.

reviews_details = df_concat[['id','name', 'host_id', 'host_name', 'date', 'reviewer_id', 'reviewer_name', 'comments']]

host_reviews = reviews_details.groupby(['host_id', 'host_name']).size().sort_values(ascending=False).to_frame(name = "number_of_reviews")
# you can show something by the code below.
# host_reviews.head()
# reviews_details.comments.head()
# reviews_details.comments.values[1]

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from config import *

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kukudexinxin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# and the basic pre processing code for comment. take out empty comments. 并对评论的各种格式进行修改，其中存在很多无意义的连接和我们并不希望进行统计的内容
reviews_details = reviews_details[reviews_details['comments'].notnull()]
#remove numbers
reviews_details['comments'] = reviews_details['comments'].str.replace('\d+', '')
#all to lowercase
reviews_details['comments'] = reviews_details['comments'].str.lower()
#remove windows new line
reviews_details['comments'] = reviews_details['comments'].str.replace('\r\n', "")
#remove stopwords (from nltk library)
stop_english = stopwords.words("english")
reviews_details['comments'] = reviews_details['comments'].apply(lambda x: " ".join([i for i in x.split()
                                                      if i not in (stop_english)]))
# remove punctuation
reviews_details['comments'] = reviews_details['comments'].str.replace('[^\w\s]'," ")
# replace x spaces by one space
reviews_details['comments'] = reviews_details['comments'].str.replace('\s+', ' ')

print(reviews_details.comments.values[2])
# Out:
# <ipython-input-6-bd8bff545eb6>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   reviews_details['comments'] = reviews_details['comments'].str.replace('\d+', '')
# <ipython-input-6-bd8bff545eb6>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   reviews_details['comments'] = reviews_details['comments'].str.replace('[^\w\s]'," ")
# <ipython-input-6-bd8bff545eb6>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   reviews_details['comments'] = reviews_details['comments'].str.replace('\s+', ' ')
# friendly generous host

# %%
import re

# %%
def is_english(row):
    return bool(re.match(r'^[a-zA-Z\s]+$', row))


reviews_details['is_english'] = reviews_details.apply(lambda row: is_english(row['comments']), axis=1)
reviews_details = reviews_details.loc[reviews_details['is_english'] == True]

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
scorer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/kukudexinxin/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#calculate sentiments of reviews
#因为有一些列非英文，我们要找到这些行,然后将它删去
def calculate_sentiment(comment):
    return(scorer.polarity_scores(comment)['compound'])

reviews_details.loc[:,'sentiment'] = reviews_details['comments'].apply(calculate_sentiment)
reviews_details[['comments','sentiment']].head()
# Out:
#                                             comments  sentiment
# 0  lovely house nice host nick completely comfort...     0.9617
# 1  nice clean cozy apartment host friendly right ...     0.8555
# 2                            friendly generous host      0.7579
# 4  lovely weekend stay girlfriend recently room c...     0.9371
# 5  nick fantastic host place beautiful clean love...     0.9337

# %%
# create positive comments
df_positive = reviews_details[reviews_details['sentiment']>0]
df_positive[['comments','sentiment']].head()
# Out:
#                                             comments  sentiment
# 0  lovely house nice host nick completely comfort...     0.9617
# 1  nice clean cozy apartment host friendly right ...     0.8555
# 2                            friendly generous host      0.7579
# 4  lovely weekend stay girlfriend recently room c...     0.9371
# 5  nick fantastic host place beautiful clean love...     0.9337

# %%
# create negative comments
df_negative = reviews_details[reviews_details['sentiment']<0]
df_negative[['comments','sentiment']].head()
# Out:
#                                               comments  sentiment
# 274           stayed room ticked boxes clean spacious     -0.0258
# 347  tired solve privately get questions answered a...    -0.6908
# 443  place nice however coming back customer servic...    -0.0772
# 481  thankyou welcoming stay especially covid times...    -0.1189
# 661  great place disappointed host s communication ...    -0.7650

# %%
# box plots of positive reviews sentiment

box = df_positive['sentiment']

plt.figure(figsize=(5,10))#设置画布的尺寸
plt.title('sentiment of boxplot',fontsize=20)#标题，并设定字号大小

#boxprops：color箱体边框色，facecolor箱体填充色；
plt.boxplot([box],patch_artist = True, boxprops = {'color':'orangered','facecolor':'pink'})

plt.show()#显示图像

# %%
# box plots of negative reviews sentiment

box = df_negative['sentiment']

plt.figure(figsize=(5,10))#设置画布的尺寸
plt.title('sentiment of boxplot',fontsize=20)#标题，并设定字号大小

#boxprops：color箱体边框色，facecolor箱体填充色；
plt.boxplot([box],patch_artist = True, boxprops = {'color':'orangered','facecolor':'pink'})

plt.show()#显示图像

# %%
#draw scatter plot of all cleansed reviews
import seaborn as sns
sns.scatterplot(data=reviews_details,x=reviews_details['sentiment'].index,y=reviews_details['sentiment'])
# Out:
# <AxesSubplot:ylabel='sentiment'>

# %%
#draw scatter plot of positive reviews
import seaborn as sns
sns.scatterplot(data=df_positive,x=df_positive['sentiment'].index,y=df_positive['sentiment'])
# Out:
# <AxesSubplot:ylabel='sentiment'>

# %%
#draw scatter plot of negative reviews
import seaborn as sns
sns.scatterplot(data=df_negative,x=df_negative['sentiment'].index,y=df_negative['sentiment'])
# Out:
# <AxesSubplot:ylabel='sentiment'>

# %%
#draw scatter plot of all cleansed reviews
import seaborn as sns
sns.scatterplot(data=reviews_details,x=reviews_details['sentiment'].index,y=reviews_details['sentiment'])

#draw scatter plot of positive reviews
import seaborn as sns
sns.scatterplot(data=df_positive,x=df_positive['sentiment'].index,y=df_positive['sentiment'])
#draw scatter plot of negative reviews
import seaborn as sns
sns.scatterplot(data=df_negative,x=df_negative['sentiment'].index,y=df_negative['sentiment'])
# Out:
# <AxesSubplot:ylabel='sentiment'>

# %%
# find the most used words using the CountVectorizer() function of sklearn.
texts = df_positive.comments.tolist()

vec = CountVectorizer().fit(texts)
bag_of_words = vec.transform(texts)
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]

cvec_df_positive = pd.DataFrame.from_records(words_freq, columns= ['words', 'counts']).sort_values(by="counts", ascending=False)

# %%
# find the most used words using the CountVectorizer() function of sklearn.
texts = df_negative.comments.tolist()

vec = CountVectorizer().fit(texts)
bag_of_words = vec.transform(texts)
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]

cvec_df_negative = pd.DataFrame.from_records(words_freq, columns= ['words', 'counts']).sort_values(by="counts", ascending=False)

# %%
cvec_df_positive.head(100)
# Out:
#              words  counts
# 59           great  142537
# 10            stay  111835
# 55           place  101640
# 60        location   95538
# 28       apartment   88316
# 26           clean   60729
# 51           would   48555
# 3             host   47369
# 53       melbourne   44566
# 45      everything   43701
# 74       recommend   42041
# 6      comfortable   38924
# 81              us   38148
# 0           lovely   36465
# 115          close   36144
# 2             nice   35033
# 33            easy   34665
# 106           good   34346
# 341        perfect   33963
# 69            well   33296
# 72          really   30928
# 1            house   29430
# 214     definitely   28725
# 25            city   28503
# 104           home   26607
# 73          highly   26400
# 71         amazing   25916
# 56       beautiful   25749
# 87            time   21982
# 54       fantastic   20837
# 299           also   20488
# 77           again   20439
# 197        helpful   19948
# 111          space   19903
# 67            walk   19896
# 544           need   19665
# 86           check   19527
# 101         thanks   19393
# 39            room   18697
# 215           back   17905
# 91           quiet   17642
# 23            tram   17571
# 229      wonderful   17012
# 129      excellent   17003
# 395         little   16901
# 29        friendly   16751
# 88   communication   16487
# 318    restaurants   16343
# 57           loved   16141
# 225           area   15921
# 46          needed   15623
# 668           view   15408
# 210          super   15354
# 140           away   15255
# 947          hosts   15179
# 202          thank   14993
# 90         staying   14992
# 43            made   14787
# 107           like   14368
# 196        enjoyed   14222
# 70             bed   13988
# 596            get   13954
# 273             it   13547
# 178          could   12891
# 127            one   12889
# 12            much   12829
# 213       spacious   12705
# 294        located   12698
# 113     convenient   12690
# 319        walking   12425
# 669          views   12149
# 161          shops   11983
# 171           even   11977
# 697         family   11931
# 120         around   11780
# 35             cbd   11526
# 100      amenities   11474
# 30           right   11390
# 96         kitchen   11382
# 65          street   11303
# 126         stayed   11236
# 114      transport   11228
# 192             in   11078
# 320       distance   10944
# 61           short   10868
# 24         station   10477
# 128          night   10312
# 82            feel   10282
# 102    recommended   10157
# 89           quick   10124
# 276     experience   10061
# 258           best   10050
# 31            next   10004
# 154             st    9948
# 324       provided    9598
# 34          access    9501
# 159          cafes    9204
# 447         airbnb    8742
# 151        central    8726
# 804         public    8704

# %%
## positive reviews
# 柱状图展示
# cvec_df.head(10).plot.barh(figsize=(15, 3), width=0.4)
plt.barh(cvec_df_positive.head(20).words.to_list(),
         cvec_df_positive.head(20).counts.to_list()
         )
plt.show()

# 词云展示
cvec_dict = dict(zip(cvec_df_positive.words, cvec_df_positive.counts))

wordcloud = WordCloud(width=800, height=400)
wordcloud.generate_from_frequencies(frequencies=cvec_dict)
plt.figure( figsize=(20,10) )
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# !pip install jieba
# Out:
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      |████████████████████████████████| 19.2 MB 7.9 MB/s eta 0:00:01
# Building wheels for collected packages: jieba
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314477 sha256=bad56ac958a5976ddb417ba4a7bbaa277dd20e5d74ab47a11f33ff3fc042a4aa
#   Stored in directory: /Users/kukudexinxin/Library/Caches/pip/wheels/ca/38/d8/dfdfe73bec1d12026b30cb7ce8da650f3f0ea2cf155ea018ae
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %%
df_positive.to_csv('airbnb_positive'.txt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-630be7a0947c> in <module>
# ----> 1 df_positive.to_csv('airbnb_positive'.txt)
#
# AttributeError: 'str' object has no attribute 'txt'

# %%
import jieba
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud

def trans_ch(txt):
  words = jieba.lcut(txt)
  newtxt = ''.join(words)
  return newtxt



txt = df_positive['comments']
mask = np.array(Image.open("airbnb_wordcloud1.png"))              
wordcloud = WordCloud(background_color="white",\
                      width = 800,\
                      height = 600,\
                      max_words = 200,\
                      max_font_size = 80,\
                      mask = mask,\
                      contour_width = 4,\
                      contour_color = 'steelblue',\
                        font_path =  "msyh.ttf"
                      ).generate(txt)
wordcloud.to_file('positive_airbnb_wordcloud.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comments'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-a6ac2754c336> in <module>
#      12
#      13
# ---> 14 txt = df_positive['comments']
#      15 mask = np.array(Image.open("airbnb_wordcloud1.png"))
#      16 wordcloud = WordCloud(background_color="white",\
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'comments'

# %%
## negative reviews
# 柱状图展示
# cvec_df.head(10).plot.barh(figsize=(15, 3), width=0.4)
plt.barh(cvec_df_negative.head(20).words.to_list(),
         cvec_df_negative.head(20).counts.to_list()
         )
plt.show()

# 词云展示
cvec_dict = dict(zip(cvec_df_negative.words, cvec_df_negative.counts))

wordcloud = WordCloud(width=800, height=400)
wordcloud.generate_from_frequencies(frequencies=cvec_dict)
plt.figure( figsize=(20,10) )
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
cvec_df_negative.head(100)
# Out:
#              words  counts
# 59           great  142537
# 10            stay  111835
# 55           place  101640
# 60        location   95538
# 28       apartment   88316
# 26           clean   60729
# 51           would   48555
# 3             host   47369
# 53       melbourne   44566
# 45      everything   43701
# 74       recommend   42041
# 6      comfortable   38924
# 81              us   38148
# 0           lovely   36465
# 115          close   36144
# 2             nice   35033
# 33            easy   34665
# 106           good   34346
# 341        perfect   33963
# 69            well   33296
# 72          really   30928
# 1            house   29430
# 214     definitely   28725
# 25            city   28503
# 104           home   26607
# 73          highly   26400
# 71         amazing   25916
# 56       beautiful   25749
# 87            time   21982
# 54       fantastic   20837
# 299           also   20488
# 77           again   20439
# 197        helpful   19948
# 111          space   19903
# 67            walk   19896
# 544           need   19665
# 86           check   19527
# 101         thanks   19393
# 39            room   18697
# 215           back   17905
# 91           quiet   17642
# 23            tram   17571
# 229      wonderful   17012
# 129      excellent   17003
# 395         little   16901
# 29        friendly   16751
# 88   communication   16487
# 318    restaurants   16343
# 57           loved   16141
# 225           area   15921
# 46          needed   15623
# 668           view   15408
# 210          super   15354
# 140           away   15255
# 947          hosts   15179
# 202          thank   14993
# 90         staying   14992
# 43            made   14787
# 107           like   14368
# 196        enjoyed   14222
# 70             bed   13988
# 596            get   13954
# 273             it   13547
# 178          could   12891
# 127            one   12889
# 12            much   12829
# 213       spacious   12705
# 294        located   12698
# 113     convenient   12690
# 319        walking   12425
# 669          views   12149
# 161          shops   11983
# 171           even   11977
# 697         family   11931
# 120         around   11780
# 35             cbd   11526
# 100      amenities   11474
# 30           right   11390
# 96         kitchen   11382
# 65          street   11303
# 126         stayed   11236
# 114      transport   11228
# 192             in   11078
# 320       distance   10944
# 61           short   10868
# 24         station   10477
# 128          night   10312
# 82            feel   10282
# 102    recommended   10157
# 89           quick   10124
# 276     experience   10061
# 258           best   10050
# 31            next   10004
# 154             st    9948
# 324       provided    9598
# 34          access    9501
# 159          cafes    9204
# 447         airbnb    8742
# 151        central    8726
# 804         public    8704

# %%
# Statistics
import pandas as pd
import numpy as np
import math as mt

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
#drop rows that 'listing_id' doesn't exist in the 'id' of 'listings' and create a new dataset'concat'
# merge dataset 'listings' and 'reviews' with the same 'id'

df_positive = pd.merge(df_concat,df_positive,how="inner",on='id')

# %%
df_positive.head()
# Out:
#    Unnamed: 0        id                            listing_url  \
# 0           0  19751625  https://www.airbnb.com/rooms/19751625
# 1           0  19751625  https://www.airbnb.com/rooms/19751625
# 2           0  19751625  https://www.airbnb.com/rooms/19751625
# 3           0  19751625  https://www.airbnb.com/rooms/19751625
# 4           0  19751625  https://www.airbnb.com/rooms/19751625
#
#         scrape_id                                       name_x  \
# 0  20200820034003  Cosy Apt with luxury Tempur bed on Lygon St
# 1  20200820034003  Cosy Apt with luxury Tempur bed on Lygon St
# 2  20200820034003  Cosy Apt with luxury Tempur bed on Lygon St
# 3  20200820034003  Cosy Apt with luxury Tempur bed on Lygon St
# 4  20200820034003  Cosy Apt with luxury Tempur bed on Lygon St
#
#                                          description  \
# 0  This charming apartment located on Lygon St in...
# 1  This charming apartment located on Lygon St in...
# 2  This charming apartment located on Lygon St in...
# 3  This charming apartment located on Lygon St in...
# 4  This charming apartment located on Lygon St in...
#
#                                neighborhood_overview  host_id_x host_name_x  \
# 0  Located on Lygon St in Carlton, you are 400m a...   13801169        Nick
# 1  Located on Lygon St in Carlton, you are 400m a...   13801169        Nick
# 2  Located on Lygon St in Carlton, you are 400m a...   13801169        Nick
# 3  Located on Lygon St in Carlton, you are 400m a...   13801169        Nick
# 4  Located on Lygon St in Carlton, you are 400m a...   13801169        Nick
#
#    host_since                 host_location  \
# 0  2014-04-02  Carlton, Victoria, Australia
# 1  2014-04-02  Carlton, Victoria, Australia
# 2  2014-04-02  Carlton, Victoria, Australia
# 3  2014-04-02  Carlton, Victoria, Australia
# 4  2014-04-02  Carlton, Victoria, Australia
#
#                                           host_about  host_response_time  \
# 0  I promise I won't be your stereotypical vegeta...                 100
# 1  I promise I won't be your stereotypical vegeta...                 100
# 2  I promise I won't be your stereotypical vegeta...                 100
# 3  I promise I won't be your stereotypical vegeta...                 100
# 4  I promise I won't be your stereotypical vegeta...                 100
#
#    host_response_rate  host_is_superhost  host_listings_count  \
# 0                 1.0                  1                  3.0
# 1                 1.0                  1                  3.0
# 2                 1.0                  1                  3.0
# 3                 1.0                  1                  3.0
# 4                 1.0                  1                  3.0
#
#                                   host_verifications  host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                     1
# 1  ['email', 'phone', 'reviews', 'jumio', 'offlin...                     1
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                     1
# 3  ['email', 'phone', 'reviews', 'jumio', 'offlin...                     1
# 4  ['email', 'phone', 'reviews', 'jumio', 'offlin...                     1
#
#    host_identity_verified neighbourhood_cleansed  latitude  longitude  \
# 0                       1              Melbourne -37.79345  144.96682
# 1                       1              Melbourne -37.79345  144.96682
# 2                       1              Melbourne -37.79345  144.96682
# 3                       1              Melbourne -37.79345  144.96682
# 4                       1              Melbourne -37.79345  144.96682
#
#                property_type     room_type  accommodates    bathrooms_text  \
# 0  Private room in apartment  Private room             2  1.5 shared baths
# 1  Private room in apartment  Private room             2  1.5 shared baths
# 2  Private room in apartment  Private room             2  1.5 shared baths
# 3  Private room in apartment  Private room             2  1.5 shared baths
# 4  Private room in apartment  Private room             2  1.5 shared baths
#
#    bedrooms  beds                                          amenities  \
# 0       1.0   1.0  ["Coffee maker", "Stove", "TV", "Free parking ...
# 1       1.0   1.0  ["Coffee maker", "Stove", "TV", "Free parking ...
# 2       1.0   1.0  ["Coffee maker", "Stove", "TV", "Free parking ...
# 3       1.0   1.0  ["Coffee maker", "Stove", "TV", "Free parking ...
# 4       1.0   1.0  ["Coffee maker", "Stove", "TV", "Free parking ...
#
#        price  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0  $7,500.00               2              90                       2
# 1  $7,500.00               2              90                       2
# 2  $7,500.00               2              90                       2
# 3  $7,500.00               2              90                       2
# 4  $7,500.00               2              90                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       4                      90                      90
# 1                       4                      90                      90
# 2                       4                      90                      90
# 3                       4                      90                      90
# 4                       4                      90                      90
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  availability_30  \
# 0                     2.1                    90.0               30
# 1                     2.1                    90.0               30
# 2                     2.1                    90.0               30
# 3                     2.1                    90.0               30
# 4                     2.1                    90.0               30
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 0               60               90                91                114
# 1               60               90                91                114
# 2               60               90                91                114
# 3               60               90                91                114
# 4               60               90                91                114
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                     22                       0   2017-10-27  2020-02-05
# 1                     22                       0   2017-10-27  2020-02-05
# 2                     22                       0   2017-10-27  2020-02-05
# 3                     22                       0   2017-10-27  2020-02-05
# 4                     22                       0   2017-10-27  2020-02-05
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  97.0                    10.0                        9.0
# 1                  97.0                    10.0                        9.0
# 2                  97.0                    10.0                        9.0
# 3                  97.0                    10.0                        9.0
# 4                  97.0                    10.0                        9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                   10.0                         10.0                    10.0
# 2                   10.0                         10.0                    10.0
# 3                   10.0                         10.0                    10.0
# 4                   10.0                         10.0                    10.0
#
#    review_scores_value  instant_bookable  calculated_host_listings_count  \
# 0                 10.0                 0                               3
# 1                 10.0                 0                               3
# 2                 10.0                 0                               3
# 3                 10.0                 0                               3
# 4                 10.0                 0                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             3
# 1                                             3
# 2                                             3
# 3                                             3
# 4                                             3
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  price_$  \
# 0                                            0               3.32   7500.0
# 1                                            0               3.32   7500.0
# 2                                            0               3.32   7500.0
# 3                                            0               3.32   7500.0
# 4                                            0               3.32   7500.0
#
#    profit_per_month      date_x  reviewer_id_x reviewer_name_x  \
# 0        256.701031  2017-10-27      155379231             Dat
# 1        256.701031  2017-10-27      155379231             Dat
# 2        256.701031  2017-10-27      155379231             Dat
# 3        256.701031  2017-10-27      155379231             Dat
# 4        256.701031  2017-10-27      155379231             Dat
#
#                                           comments_x  \
# 0  That is the lovely house with the nice host, N...
# 1  That is the lovely house with the nice host, N...
# 2  That is the lovely house with the nice host, N...
# 3  That is the lovely house with the nice host, N...
# 4  That is the lovely house with the nice host, N...
#
#                                         name_y  host_id_y host_name_y  \
# 0  Cosy Apt with luxury Tempur bed on Lygon St   13801169        Nick
# 1  Cosy Apt with luxury Tempur bed on Lygon St   13801169        Nick
# 2  Cosy Apt with luxury Tempur bed on Lygon St   13801169        Nick
# 3  Cosy Apt with luxury Tempur bed on Lygon St   13801169        Nick
# 4  Cosy Apt with luxury Tempur bed on Lygon St   13801169        Nick
#
#        date_y  reviewer_id_y reviewer_name_y  \
# 0  2017-10-27      155379231             Dat
# 1  2017-10-30      155868665             Tom
# 2  2017-11-07      106028610        Dongchen
# 3  2017-11-18       62850957         Derrick
# 4  2017-11-22       25291920            Hyon
#
#                                           comments_y  is_english  sentiment
# 0  lovely house nice host nick completely comfort...        True     0.9617
# 1  nice clean cozy apartment host friendly right ...        True     0.8555
# 2                            friendly generous host         True     0.7579
# 3  lovely weekend stay girlfriend recently room c...        True     0.9371
# 4  nick fantastic host place beautiful clean love...        True     0.9337
